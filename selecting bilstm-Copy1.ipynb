# %% [markdown]
# ## Load

# %%
import pandas as pd
data = pd.read_csv('dataset.tsv', sep='\t', index_col=0)

# %%
data.clean_text = data.clean_text.apply(eval)
data.bow = data.bow.apply(eval)
data.entities = data.entities.apply(eval)

# %%
data.index = pd.Index(list(range(len(data))))

# %% [markdown]
# ## LDA features

# %%
from gensim.corpora import Dictionary
from gensim.models import LdaModel, LdaMulticore

# %%
corpus = data.bow
dictionary = Dictionary(documents=data.clean_text.values)
print("Found {} words.".format(len(dictionary.values())))
# Out:
# Found 1882 words.

# %%
num_topics = 400
LDAmodel = LdaMulticore(corpus=corpus,
                        id2word=dictionary,
                        num_topics=num_topics,
                        workers=4,
                        chunksize=4000,
                        passes=7,
                        alpha='asymmetric')
# Out:
# /home/alice/Mines/paradec/paradec/lib/python3.6/site-packages/gensim/models/ldamodel.py:1023: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
import numpy as np

# %%
def document_to_lda_features_by_word(lda_model, dictionary, document):
    if len(document)==0:
        return np.zeros(lda_model.num_topics, dtype="float32").reshape(1, lda_model.num_topics)
    featureVec = np.array(LDAmodel.get_document_topics(
        dictionary.doc2bow([document[0]]), minimum_probability=0))[:,1].reshape(1, lda_model.num_topics)
    for word in document[1:]:
        featureVec = np.vstack([featureVec,
                                np.array(LDAmodel.get_document_topics(
                                    dictionary.doc2bow([word]), minimum_probability=0))[:,1]])
    return featureVec

# %% [markdown]
# ## NN

# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ## BiLSTM by word

# %%
lengths = data['clean_text'].apply(len).sort_values(ascending=False)
sorted_idx = lengths[lengths>0].index
seq_tensor = nn.utils.rnn.pad_sequence(tuple(data.loc[sorted_idx]['clean_text'].apply(lambda x: 
                                                                    torch.FloatTensor(
                                                                    #    get_w2v_features_by_word(W2Vmodel, x)
                                                                        torch.from_numpy(document_to_lda_features_by_word(LDAmodel, dictionary, x)).float()
                                                                    ))))
lengths = lengths[lengths>0].values

# %%
len(lengths), len(sorted_idx)
# Out:
# (3272, 3272)

# %%
X_w2v_packed = nn.utils.rnn.pack_padded_sequence(seq_tensor, lengths)
#padded = pad_packed_sequence(out, batch_first=True)

# %%
num_topics = 400
output_size = 64

# %%
lstm = nn.LSTM(num_topics, output_size, bidirectional=True, num_layers=1)
packed_output, (ht, ct) = lstm(X_w2v_packed)
output, _ = nn.utils.rnn.pad_packed_sequence(packed_output)

#final hidden state
print (ht[-1])
# Out:
# tensor([[ 0.0124,  0.0381,  0.0172,  ...,  0.0072,  0.0309,  0.0951],
#         [ 0.0123,  0.0443, -0.0004,  ...,  0.0038,  0.0090,  0.0567],
#         [ 0.0034,  0.0536,  0.0003,  ...,  0.0135,  0.0128,  0.0603],
#         ...,
#         [ 0.0103,  0.0362, -0.0057,  ...,  0.0099,  0.0127,  0.0362],
#         [ 0.0103,  0.0362, -0.0057,  ...,  0.0099,  0.0127,  0.0362],
#         [ 0.0103,  0.0362, -0.0057,  ...,  0.0099,  0.0127,  0.0362]],
#        grad_fn=<SelectBackward>)

# %%
mxpl = nn.AdaptiveMaxPool1d(1)

# %%
mxpl(output.permute(1,2,0)).squeeze(2)
# Out:
# tensor([[ 0.0032, -0.0327,  0.1160,  ...,  0.0302,  0.0309,  0.0951],
#         [ 0.0154, -0.0115,  0.1186,  ...,  0.0275,  0.0290,  0.0567],
#         [ 0.0106, -0.0222,  0.1109,  ...,  0.0298,  0.0161,  0.0623],
#         ...,
#         [ 0.0023,  0.0000,  0.0344,  ...,  0.0099,  0.0127,  0.0362],
#         [ 0.0023,  0.0000,  0.0344,  ...,  0.0099,  0.0127,  0.0362],
#         [ 0.0023,  0.0000,  0.0344,  ...,  0.0099,  0.0127,  0.0362]],
#        grad_fn=<SqueezeBackward1>)

# %%
output.size()
# Out:
# torch.Size([12, 3272, 400])

# %%
ht[-1].size()
# Out:
# torch.Size([3272, 64])

# %%
ht[-1][pd.DataFrame(sorted_idx).sort_values(0).index]
# Out:
# tensor([[ 0.0056, -0.0069, -0.0214,  ...,  0.0283,  0.0173, -0.0300],
#         [ 0.0053, -0.0063, -0.0206,  ...,  0.0287,  0.0185, -0.0308],
#         [ 0.0047, -0.0068, -0.0206,  ...,  0.0280,  0.0176, -0.0296],
#         ...,
#         [ 0.0054, -0.0079, -0.0205,  ...,  0.0243,  0.0127, -0.0232],
#         [ 0.0053, -0.0079, -0.0204,  ...,  0.0242,  0.0121, -0.0230],
#         [ 0.0052, -0.0083, -0.0176,  ...,  0.0203,  0.0094, -0.0179]],
#        grad_fn=<TakeBackward>)

# %%
X_bilstm_ht =mxpl(ht.permute(1,2,0)).squeeze(2) # ht[-1]#[pd.DataFrame(sorted_idx).sort_values(0).index]

# %% [markdown]
# ## Dataset

# %%
K = len(data['intent'].unique())

# %%
X = X_bilstm_ht.detach().numpy()
y = data.loc[sorted_idx]['intent']

# %%
X.shape, y.shape
# Out:
# ((3272, 64), (3272,))

# %% [markdown]
# ---

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering

# %%
from sklearn.mixture import GaussianMixture

# %%
km = KMeans(K).fit(X)

# %%
km = AgglomerativeClustering(K).fit(X)

# %%
km = GaussianMixture(K, tol=1e-6, max_iter=500).fit(X)

# %% [markdown]
# ---

# %%
# %matplotlib inline

# %%
comp = pd.DataFrame(data.loc[sorted_idx][['text', 'intent']])

# %%
comp['clusters'] = km.predict(X)

# %%
comp['clusters'] = km.labels_

# %%
comp['clusters'].hist()

# %%
pd.pivot_table(comp, index='intent', columns='clusters', aggfunc=len, fill_value=0)\
            .style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row0_col0 {
#             background-color:  #fbf4f9;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row0_col1 {
#             background-color:  #f8f1f8;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row0_col2 {
#             background-color:  #f0eaf4;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row0_col3 {
#             background-color:  #fff7fb;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row2_col18 {
#             background-color:  #c5cce3;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row2_col19 {
#             background-color:  #c5cce3;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col0 {
#             background-color:  #fff7fb;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col1 {
#             background-color:  #acc0dd;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col2 {
#             background-color:  #f4eef6;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col3 {
#             background-color:  #fff7fb;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col4 {
#             background-color:  #fff7fb;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col5 {
#             background-color:  #509ac6;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col6 {
#             background-color:  #91b5d6;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col7 {
#             background-color:  #fff7fb;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col8 {
#             background-color:  #023858;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col9 {
#             background-color:  #d9d8ea;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col10 {
#             background-color:  #fff7fb;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col11 {
#             background-color:  #2f8bbe;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col12 {
#             background-color:  #fff7fb;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col13 {
#             background-color:  #f4eef6;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col14 {
#             background-color:  #509ac6;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46d836424b3row3_col15 {
#             background-color:  #fff7fb;
#         }    #T_3ddb2c9a_225e_11e9_9d34_b46

# %%
from sklearn.metrics import *

# %%
def purity_score(y_true, y_pred):
    contingency_matrix = cluster.contingency_matrix(y_true, y_pred)
    return np.sum(np.amax(contingency_matrix, axis=0)) / np.sum(contingency_matrix)

# %%
(
    purity_score(comp['intent'], comp['clusters']),
    silhouette_score(X, comp['clusters']),
    homogeneity_score(comp['intent'], comp['clusters']),
    completeness_score(comp['intent'], comp['clusters']),
)
# Out:
# (0.2707823960880196, 0.19954675, 0.21862049659874672, 0.2157083883569415)

# %% [markdown]
# ## GO

# %%
[2**i for i in range(5,12)]
# Out:
# [32, 64, 128, 256, 512, 1024, 2048]

# %%
raw_results = []
cms = []
np.random.seed(0)
num_topics=400

for output_size in [64]:
    lstm = nn.LSTM(num_topics, output_size, num_layers=1, bidirectional=True)
    packed_output, (ht, ct) = lstm(X_w2v_packed)
    output, _ = nn.utils.rnn.pad_packed_sequence(packed_output)
    X_bilstm_ht = ht[-1]#[pd.DataFrame(sorted_idx).sort_values(0).index]
    #X = mxpl(output.permute(1,2,0)).squeeze(2).detach().numpy()
    X = X_bilstm_ht.detach().numpy()

    print('%d features'%output_size)
    for model in [KMeans, AgglomerativeClustering, GaussianMixture]:
        print('\t %s'%str(model).split('.')[-1][:-2])
        try:
            km = model(K, tol=1e-6, max_iter=500).fit(X)
        except:
            km = model(K).fit(X)


        comp = pd.DataFrame(data.loc[sorted_idx][['text', 'intent']])
        try:
            comp['clusters'] = km.labels_
        except:
            comp['clusters'] = km.predict(X)

        comp['clusters'].hist().get_figure().savefig('lda/hist_%d.pdf'%num_topics)
        cms += [pd.pivot_table(comp, index='intent', columns='clusters', aggfunc=len, fill_value=0)\
                    .style.background_gradient(axis=1)]
        raw_results += [(
            purity_score(comp['intent'], comp['clusters']),
            silhouette_score(X, comp['clusters']),
            homogeneity_score(comp['intent'], comp['clusters']),
            completeness_score(comp['intent'], comp['clusters']),
            output_size,
            str(model).split('.')[-1][:-2])
        ]
# Out:
# 64 features
# 	 KMeans
# 	 AgglomerativeClustering
# 	 GaussianMixture

# %%
results = pd.DataFrame(raw_results,
                       columns=['purity', 'silhouette', 'homogeneity', 
                                'completeness', 'features num', 'model'])

# %%
import seaborn as sns; sns.set()

# %%
results.to_csv('bilstm_lda/scores_output_size1.csv')

# %%
results.style.background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_4a22beda_2260_11e9_9d34_b46d836424b3row0_col0 {
#             background-color:  #023858;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row0_col1 {
#             background-color:  #023858;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row0_col2 {
#             background-color:  #023858;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row0_col3 {
#             background-color:  #046299;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row0_col4 {
#             background-color:  #fff7fb;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row1_col0 {
#             background-color:  #0771b1;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row1_col1 {
#             background-color:  #62a2cb;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row1_col2 {
#             background-color:  #046097;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row1_col3 {
#             background-color:  #023858;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row1_col4 {
#             background-color:  #fff7fb;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row2_col0 {
#             background-color:  #fff7fb;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row2_col1 {
#             background-color:  #fff7fb;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row2_col2 {
#             background-color:  #fff7fb;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row2_col3 {
#             background-color:  #fff7fb;
#         }    #T_4a22beda_2260_11e9_9d34_b46d836424b3row2_col4 {
#             background-color:  #fff7fb;
#         }</style>
# <table id="T_4a22beda_2260_11e9_9d34_b46d836424b3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0"
>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >purity</th>
#         <th class="col_heading level0 col1" >silhouette</th>
#         <th class="col_heading level0 col2" >homogeneity</th>
#         <th class="col_heading level0 col3" >completeness</th>
#     </tr>    <tr>
#         <th class="index_name level0" >features num</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_bab91a2e_225e_11e9_9d34_b46d836424b3level0_row0" class="row_heading level0 row0" >64</th>
#         <td id="T_bab91a2e_225e_11e9_9d34_b46d836424b3row0_col0" class="data row0 col0" >0.256011</td>
#         <td id="T_bab91a2e_225e_11e9_9d34_b46d836424b3row0_col1" class="data row0 col1" >0.183609</td>
#         <td id="T_bab91a2e_225e_11e9_9d34_b46d836424b3row0_col2" class="data row0 col2" >0.200849</td>
#         <td id="T_bab91a2e_225e_11e9_9d34_b46d836424b3row0_col3" class="data row0 col3" >0.20462</td>
#     </tr></tbody>
# </table>

# %%
results.groupby('features num').mean().plot()

# %%
cms[9]
# Out:
# <style  type="text/css" >
#     #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col0 {
#             background-color:  #fff7fb;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col1 {
#             background-color:  #f0eaf4;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col2 {
#             background-color:  #67a4cc;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col3 {
#             background-color:  #f4edf6;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col4 {
#             background-color:  #fff7fb;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col5 {
#             background-color:  #d6d6e9;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col6 {
#             background-color:  #d6d6e9;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col7 {
#             background-color:  #2c89bd;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col8 {
#             background-color:  #fff7fb;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col9 {
#             background-color:  #ece7f2;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col10 {
#             background-color:  #e7e3f0;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col11 {
#             background-color:  #f8f1f8;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col12 {
#             background-color:  #e1dfed;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col13 {
#             background-color:  #fff7fb;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col14 {
#             background-color:  #023858;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col15 {
#             background-color:  #fff7fb;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col16 {
#             background-color:  #d6d6e9;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row0_col17 {
#             background-color:  #fbf4f9;
#         }    #T_bff5f734_225c_11e9_9d34_b46d836424b3row3_col15 {
#             background-color:  #fff7fb;
#         }    #T_bff5f734_225c_11e9_9d34_b46

# %% [markdown]
# ## Quick easy classifier

# %% [markdown]
# - 10 fold cross validation on 100 examples from labelled data
# - Feed forward network
# - Input = sequence of word representations

# %%
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt

def balanced_sample_maker(X, y, sample_size, random_seed=42):
    uniq_levels = np.unique(y)
    uniq_counts = {level: sum(y == level) for level in uniq_levels}

    if not random_seed is None:
        np.random.seed(random_seed)

    # find observation index of each class levels
    groupby_levels = {}
    for ii, level in enumerate(uniq_levels):
        obs_idx = [idx for idx, val in enumerate(y) if val == level]
        groupby_levels[level] = obs_idx
    # oversampling on observations of each label
    balanced_copy_idx = []
    for gb_level, gb_idx in groupby_levels.items():
        over_sample_idx = np.random.choice(gb_idx, size=sample_size, replace=True).tolist()
        balanced_copy_idx+=over_sample_idx
    np.random.shuffle(balanced_copy_idx)

    data_train=X[balanced_copy_idx]
    labels_train=y[balanced_copy_idx]
    if  ((len(data_train)) == (sample_size*len(uniq_levels))):
        print('number of sampled example ', sample_size*len(uniq_levels), 'number of sample per class ', sample_size, ' #classes: ', len(list(set(uniq_levels))))
    else:
        print('number of samples is wrong ')

    labels, values = zip(*Counter(labels_train).items())
    print('number of classes ', len(list(set(labels_train))))
    check = all(x == values[0] for x in values)
    print(check)
    if check == True:
        print('Good all classes have the same number of examples')
    else:
        print('Repeat again your sampling your classes are not balanced')
    indexes = np.arange(len(labels))
    width = 0.5
    plt.bar(indexes, values, width)
    plt.xticks(indexes + width * 0.5, labels)
    plt.show()
    return data_train,labels_train

# %%
X = X_bilstm_ht.detach().numpy()
y = data.loc[sorted_idx]['intent']
#y = data['intent']

# %%
X_train,y_train=balanced_sample_maker(X,y,50)
# Out:
# number of sampled example  1000 number of sample per class  50  #classes:  20
# number of classes  21
# False
# Repeat again your sampling your classes are not balanced

# %%
pd.DataFrame([y_train.values, y_train.values]).T.groupby(0).count().sort_values(1).tail()
# Out:
#                1
# 0
# risk          57
# pain          78
# treatment     86
# infoPatient   93
# sleep        134

# %%
y_train = y_train.fillna('hello')

# %%
bad_df = y.index.isin(y_train.index)
X_test = pd.DataFrame(X)[~bad_df]
y_test = data.loc[sorted_idx][~bad_df]['intent']

# %%
from sklearn.svm import SVC

# %%
clf = SVC(kernel='linear', C=1, random_state=0).fit(X_train, y_train)

# %%
clf.score(X_test, y_test)
# Out:
# 0.05681332763776164

# %%
clf.predict(X_test[:40])
# Out:
# array(['treatment', 'treatment', 'treatment', 'treatment', 'treatment',
#        'treatment', 'treatment', 'treatment', 'treatment', 'treatment',
#        'treatment', 'treatment', 'treatment', 'treatment', 'treatment',
#        'treatment', 'treatment', 'treatment', 'treatment', 'treatment',
#        'treatment', 'treatment', 'treatment', 'treatment', 'treatment',
#        'treatment', 'treatment', 'treatment', 'treatment', 'treatment',
#        'treatment', 'treatment', 'treatment', 'treatment', 'treatment',
#        'treatment', 'treatment', 'treatment', 'treatment', 'treatment'],
#       dtype=object)

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_scores = cross_val_score(clf, X_test, y_test, cv=10)

# %%
cv_scores
# Out:
# array([0.1147541 , 0.17283951, 0.23849372, 0.2278481 , 0.21367521,
#        0.26293103, 0.27391304, 0.29694323, 0.22907489, 0.19469027])

# %%
print('{:2.3} + {:2.3}%'.format(np.mean(cv_scores), np.std(cv_scores)))
# Out:
# 0.223 + 0.0501%

# %%
from sklearn.metrics import confusion_matrix

# %%
clf_res = pd.DataFrame([clf.predict(X_test), y_test]).T
clf_res.columns = ['class', 'intent']

# %%
cm = pd.DataFrame(confusion_matrix(clf_res['intent'], clf_res['class']), 
             index=clf.classes_, columns=clf.classes_)

# %%
clf_res.groupby('class').count()
# Out:
#            intent
# class
# sleep        1587
# treatment     754

# %%
clf_res.groupby('intent').count()
# Out:
#                  class
# intent
# activity           132
# agree               55
# alcohol             76
# bye                 58
# disagree            42
# drugAddiction      152
# eatingDisorders    120
# fallback            42
# hello               74
# incomprehension     89
# infoPatient        204
# negativeEmo        100
# pain               203
# pathology           96
# positiveEmo        103
# risk               101
# sleep              274
# smoking             78
# social              87
# treatment          255

# %%
cm.style.set_table_styles(
    [dict(selector="th",props=[('max-width', '120px')]),
        dict(selector="th.col_heading",
                 props=[("writing-mode", "vertical-rl"), 
                        ('transform', 'rotateZ(180deg)'),
                        ])]
).background_gradient(axis=0)
# Out:
# <style  type="text/css" >
#     #T_3726e78e_0519_11e9_a836_b46d836424b3 th {
#           max-width: 120px;
#     }    #T_3726e78e_0519_11e9_a836_b46d836424b3 th.col_heading {
#           writing-mode: vertical-rl;
#           transform: rotateZ(180deg);
#     }    #T_3726e78e_0519_11e9_a836_b46d836424b3row0_col0 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row0_col1 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row0_col2 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row0_col3 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row0_col4 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row0_col5 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row0_col6 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row0_col7 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row0_col8 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row0_col9 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row0_col10 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row0_col11 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row0_col12 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row3_col11 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row3_col12 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_11e9_a836_b46d836424b3row3_col13 {
#             background-color:  #fff7fb;
#         }    #T_3726e78e_0519_

# %%
clf_res.groupby('intent').count().sort_values('class').plot(kind='barh')

# %%
data.groupby('intent').count()['text'].sort_values().plot(kind='barh')

# %%
data.loc[0]
# Out:
# entities             [{'start': 34, 'end': 38, 'value': 'wine', 'en...
# intent                                                         alcohol
# text                 i’m drinking at least a bottle of wine a day i...
# tokenized_text       [i, m, drinking, at, least, a, bottle, of, win...
# stopwords_removed    [i, m, drinking, at, least, a, bottle, of, win...
# lemmatized_text      [i, m, drinking, at, least, a, bottle, of, win...
# stemmed_text         [i, m, drink, at, least, a, bottl, of, wine, a...
# bow                  [(0, 2), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1...
# w2v_features         [-0.023403363, -0.00012617472, -0.007538838, 0...
# glove_features       [0.5747946, 0.19084111, -0.12595873, -0.176687...
# Name: 0, dtype: object

# %% [markdown]
# ## Label new data

# %%
import json

# %%
new_data = list(map(lambda x: x['post'], json.loads(open('subset.json', 'r').read())))[:100]

# %%
new_data = sum(list(map(lambda x: x.split('\n'), new_data)), [])

# %%
new_data = sum(list(map(lambda x: x.split('.'), new_data)), [])

# %%
new_data = list(map(lambda x: x.strip(), new_data))

# %%
new_data = list(filter(lambda x: len(x)>0, new_data))

# %%
new_dt = pd.DataFrame(new_data, columns=['text'])

# %%
lda_preprocessing(new_dt)

# %%
new_dt['stem_len'] = new_dt.stemmed_text.apply(len)

# %%
new_dt[(new_dt['stem_len']>0)&(new_dt['stem_len']<=10)]
# Out:
#                                                     text  \
# 0      how about a divorce support group for those wh...
# 1      i know when i was divorced 6 years ago after 2...
# 2                        anyone have any other comments?
# 3             i'm welcoming all suggestions and comments
# 4                          i just need some sound advice
# 5                                   i have a dd who is 2
# 6      she is very smart, tall for her age, speaks in...
# 7          she appears to be 3 instead of just turning 2
# 8                          she goes to daycare full-time
# 9      it's an in-home daycare with only one other ch...
# 10                      a boy (andy) who is one year old
# 11     a few weeks ago she came home with a red mark ...
# 12     daycare mother said the little boy had hit her...
# 13                                     okay, no big deal
# 14     then she mentioned that my dd likes to push an...
# 15     i don't have any friends with children, so the...
# 16     so, yesterday when i got to daycare to pick my...
# 17        she was on the floor playing with the children
# 18     i said, what's wrong?  she said "your dd is ab...
# 20     she went in to find him on the floor and as th...
# 21     i was confused as to what exactly i was suppos...
# 22     so finally i said well if i had been here, i w...
# 23     5 hours later is not the time, in my opinion, ...
# 24     i told the daycare mother that i was not oppos...
# 25     and i thought she had told me she put her in t...
# 26         i'm really at my wits end with this situation
# 27     am i not doing what needs to be done?  i feel ...
# 29                                        please comment
# 30                              i really need some input
# 31                              25 views and no opinions
# ...                                                  ...
# 48836  i kinda freaked out and had to leave the offic...
# 48837  i need to phone back to double check the thyro...
# 48838  well, i know it's hard but it's good that you ...
# 48839          pcos really is very common and manageable
# 48840  about 10% of the reproductive age female popul...
# 48841  i think it is very good that you are trying to...
# 48842  you may also have to start metformin, since it...
# 48843  these syndromes all seem to be tied together- ...
# 48844  there is a question mark for me about the pcos...
# 48845  but the insulin resistance diagnosis is starti...
# 48846                         i also have hypothyroidism
# 48847                           all of this is treatable
# 48848  it is good that you know because now you can t...
# 48849  please do not worry- this is not a scary diagn...
# 48850  you must have had some inkling that you had so...
# 48851           are you trying to get pregnant? i forget
# 48852                                 my mother had pcos
# 48853  i'm 22 and have been experiencing some of the ...
# 48854  i got my blood test done in march and my prola...
# 48855                      which is has been fine for me
# 48856  but over the last few months, i've noticed tha...
# 48857  my knee will occasionally be sore, i'm really ...
# 48858  a lot of symptoms that's point toward hyperthy...
# 48859  i met with my doctor and she ordered some bloo...
# 48860  they came in but i'm not sure how to decipher ...
# 48861                            can anyone help me out?
# 48863                                             tsh: 1
# 48864                                                 15
# 48865                                         freet4 = 0
# 48866                                                  9
#
#                                           tokenized_text  \
# 0      [how, about, a, divorce, support, group, for, ...
# 1      [i, know, when, i, was, divorced, 6, years, ag...
# 2                [anyone, have, any, other, comments, ?]
# 3      [i, m, welcoming, all, suggestions, and, comme...
# 4                   [i, just, need, some, sound, advice]
# 5                           [i, have, a, dd, who, is, 2]
# 6      [she, is, very, smart, tall, for, her, age, sp...
# 7      [she, appears, to, be, 3, instead, of, just, t...
# 8                     [she, goes, to, daycare, fulltime]
# 9      [it, s, an, inhome, daycare, with, only, one, ...
# 10               [a, boy, andy, who, is, one, year, old]
# 11     [a, few, weeks, ago, she, came, home, with, a,...
# 12     [daycare, mother, said, the, little, boy, had,...
# 13                                 [okay, no, big, deal]
# 14     [then, she, mentioned, that, my, dd, likes, to...
# 15     [i, do, nt, have, any, friends, with, children...
# 16     [so, yesterday, when, i, got, to, daycare, to,...
# 17     [she, was, on, the, floor, playing, with, the,...
# 18     [i, said, what, s, wrong, ?, she, said, your, ...
# 20     [she, went, in, to, find, him, on, the, floor,...
# 21     [i, was, confused, as, to, what, exactly, i, w...
# 22     [so, finally, i, said, well, if, i, had, been,...
# 23     [5, hours, later, is, not, the, time, in, my, ...
# 24     [i, told, the, daycare, mother, that, i, was, ...
# 25     [and, i, thought, she, had, told, me, she, put...
# 26     [i, m, really, at, my, wits, end, with, this, ...
# 27     [am, i, not, doing, what, needs, to, be, done,...
# 29                                     [please, comment]
# 30                        [i, really, need, some, input]
# 31                        [25, views, and, no, opinions]
# ...                                                  ...
# 48836  [i, kinda, freaked, out, and, had, to, leave, ...
# 48837  [i, need, to, phone, back, to, double, check, ...
# 48838  [well, i, know, it, s, hard, but, it, s, good,...
# 48839  [pcos, really, is, very, common, and, manageable]
# 48840  [about, 10, of, the, reproductive, age, female...
# 48841  [i, think, it, is, very, good, that, you, are,...
# 48842  [you, may, also, have, to, start, metformin, s...
# 48843  [these, syndromes, all, seem, to, be, tied, to...
# 48844  [there, is, a, question, mark, for, me, about,...
# 48845  [but, the, insulin, resistance, diagnosis, is,...
# 48846                    [i, also, have, hypothyroidism]
# 48847                     [all, of, this, is, treatable]
# 48848  [it, is, good, that, you, know, because, now, ...
# 48849  [please, do, not, worry, this, is, not, a, sca...
# 48850  [you, must, have, had, some, inkling, that, yo...
# 48851  [are, you, trying, to, get, pregnant, ?, i, fo...
# 48852                            [my, mother, had, pcos]
# 48853  [i, m, 22, and, have, been, experiencing, some...
# 48854  [i, got, my, blood, test, done, in, march, and...
# 48855              [which, is, has, been, fine, for, me]
# 48856  [but, over, the, last, few, months, i, ve, not...
# 48857  [my, knee, will, occasionally, be, sore, i, m,...
# 48858  [a, lot, of, symptoms, that, s, point, toward,...
# 48859  [i, met, with, my, doctor, and, she, ordered, ...
# 48860  [they, came, in, but, i, m, not, sure, how, to...
# 48861                    [can, anyone, help, me, out, ?]
# 48863                                           [tsh, 1]
# 48864                                               [15]
# 48865                                        [freet4, 0]
# 48866                                                [9]
#
#                                        stopwords_removed  \
# 0      [divorce, support, group, process, divorced, n...
# 1      [divorced, 6, years, ago, 23, years, marriage,...
# 2                                          [comments, ?]
# 3                     [welcoming, suggestions, comments]
# 4                                        [sound, advice]
# 5                                                [dd, 2]
# 6        [smart, tall, age, speaks, complete, sentences]
# 7                               [appears, 3, turning, 2]
# 8                                    [daycare, fulltime]
# 9                               [inhome, daycare, child]
# 10                                     [boy, andy, year]
# 11                   [weeks, ago, red, mark, eye, asked]
# 12                      [daycare, mother, boy, hit, toy]
# 13                                           [big, deal]
# 14                    [mentioned, dd, likes, push, andy]
# 15      [nt, friends, children, time, dd, kids, daycare]
# 16     [yesterday, daycare, pick, child, daycare, mot...
# 17                            [floor, playing, children]
# 18                         [wrong, ?, dd, abusing, andy]
# 20              [find, floor, day, black, eye, appeared]
# 21                         [confused, exactly, supposed]
# 22                        [finally, well, corrected, nt]
# 23                    [5, hours, time, opinion, correct]
# 24     [told, daycare, mother, opposed, putting, dd, ...
# 25                                 [thought, told, time]
# 26                                     [wits, situation]
# 27     [?, feel, paying, good, money, child, care, wo...
# 29                                             [comment]
# 30                                               [input]
# 31                                 [25, views, opinions]
# ...                                                  ...
# 48836  [kinda, freaked, leave, office, friend, walk, ...
# 48837            [phone, double, check, thyroid, levels]
# 48838   [well, hard, good, definitive, diagnosis, treat]
# 48839                         [pcos, common, manageable]
# 48840  [10, reproductive, age, female, population, pcos]
# 48841  [good, cut, sugar, consumption, big, contribut...
# 48842            [start, metformin, insulin, resistance]
# 48843  [syndromes, tied, insulin, resistance, pcos, h...
# 48844  [question, mark, pcos, hormonal, markers, over...
# 48845  [insulin, resistance, diagnosis, starting, rea...
# 48846                                   [hypothyroidism]
# 48847                                        [treatable]
# 48848         [good, steps, healthy, reversing, process]
# 48849                          [worry, scary, diagnosis]
# 48850                         [inkling, symptoms, treat]
# 48851                              [pregnant, ?, forget]
# 48852                                     [mother, pcos]
# 48853                       [22, experiencing, symptoms]
# 48854  [blood, test, march, prolactin, level, 32ml, s...
# 48855                                             [fine]
# 48856               [months, ve, noticed, bit, crappier]
# 48857  [knee, will, occasionally, sore, sleepy, lot, ...
# 48858  [lot, symptoms, point, hyperthyroidism, thinki...
# 48859                      [met, doctor, ordered, blood]
# 48860                                   [sure, decipher]
# 48861                                          [help, ?]
# 48863                                           [tsh, 1]
# 48864                                               [15]
# 48865                                        [freet4, 0]
# 48866                                                [9]
#
#                                          lemmatized_text  \
# 0      [divorce, support, group, process, divorced, n...
# 1      [divorced, 6, year, ago, 23, year, marriage, g...
# 2                                           [comment, ?]
# 3                       [welcoming, suggestion, comment]
# 4                                        [sound, advice]
# 5                                                [dd, 2]
# 6         [smart, tall, age, speaks, complete, sentence]
# 7                               [appears, 3, turning, 2]
# 8                                    [daycare, fulltime]
# 9                               [inhome, daycare, child]
# 10                                     [boy, andy, year]
# 11                    [week, ago, red, mark, eye, asked]
# 12                      [daycare, mother, boy, hit, toy]
# 13                                           [big, deal]
# 14                     [mentioned, dd, like, push, andy]
# 15           [nt, friend, child, time, dd, kid, daycare]
# 16     [yesterday, daycare, pick, child, daycare, mot...
# 17                               [floor, playing, child]
# 18                         [wrong, ?, dd, abusing, andy]
# 20              [find, floor, day, black, eye, appeared]
# 21                         [confused, exactly, supposed]
# 22                        [finally, well, corrected, nt]
# 23                     [5, hour, time, opinion, correct]
# 24     [told, daycare, mother, opposed, putting, dd, ...
# 25                                 [thought, told, time]
# 26                                      [wit, situation]
# 27     [?, feel, paying, good, money, child, care, wo...
# 29                                             [comment]
# 30                                               [input]
# 31                                   [25, view, opinion]
# ...                                                  ...
# 48836  [kinda, freaked, leave, office, friend, walk, ...
# 48837             [phone, double, check, thyroid, level]
# 48838   [well, hard, good, definitive, diagnosis, treat]
# 48839                         [pcos, common, manageable]
# 48840  [10, reproductive, age, female, population, pcos]
# 48841  [good, cut, sugar, consumption, big, contribut...
# 48842            [start, metformin, insulin, resistance]
# 48843  [syndrome, tied, insulin, resistance, pcos, hy...
# 48844  [question, mark, pcos, hormonal, marker, overw...
# 48845  [insulin, resistance, diagnosis, starting, rea...
# 48846                                   [hypothyroidism]
# 48847                                        [treatable]
# 48848          [good, step, healthy, reversing, process]
# 48849                          [worry, scary, diagnosis]
# 48850                          [inkling, symptom, treat]
# 48851                              [pregnant, ?, forget]
# 48852                                     [mother, pcos]
# 48853                        [22, experiencing, symptom]
# 48854  [blood, test, march, prolactin, level, 32ml, s...
# 48855                                             [fine]
# 48856                [month, ve, noticed, bit, crappier]
# 48857  [knee, will, occasionally, sore, sleepy, lot, ...
# 48858  [lot, symptom, point, hyperthyroidism, thinkin...
# 48859                      [met, doctor, ordered, blood]
# 48860                                   [sure, decipher]
# 48861                                          [help, ?]
# 48863                                           [tsh, 1]
# 48864                                               [15]
# 48865                                        [freet4, 0]
# 48866                                                [9]
#
#                                             stemmed_text  \
# 0      [divorc, support, group, process, divorc, nt, ...
# 1      [divorc, 6, year, ago, 23, year, marriag, god,...
# 2                                           [comment, ?]
# 3                             [welcom, suggest, comment]
# 4                                         [sound, advic]
# 5                                                [dd, 2]
# 6            [smart, tall, age, speak, complet, sentenc]
# 7                                   [appear, 3, turn, 2]
# 8                                      [daycar, fulltim]
# 9                                 [inhom, daycar, child]
# 10                                     [boy, andi, year]
# 11                      [week, ago, red, mark, eye, ask]
# 12                       [daycar, mother, boy, hit, toy]
# 13                                           [big, deal]
# 14                       [mention, dd, like, push, andi]
# 15            [nt, friend, child, time, dd, kid, daycar]
# 16     [yesterday, daycar, pick, child, daycar, mothe...
# 17                                  [floor, play, child]
# 18                            [wrong, ?, dd, abus, andi]
# 20                [find, floor, day, black, eye, appear]
# 21                             [confus, exactli, suppos]
# 22                            [final, well, correct, nt]
# 23                     [5, hour, time, opinion, correct]
# 24          [told, daycar, mother, oppos, put, dd, time]
# 25                                 [thought, told, time]
# 26                                         [wit, situat]
# 27     [?, feel, pay, good, money, child, care, work,...
# 29                                             [comment]
# 30                                               [input]
# 31                                   [25, view, opinion]
# ...                                                  ...
# 48836  [kinda, freak, leav, offic, friend, walk, expect]
# 48837              [phone, doubl, check, thyroid, level]
# 48838       [well, hard, good, definit, diagnosi, treat]
# 48839                               [pco, common, manag]
# 48840            [10, reproduct, age, femal, popul, pco]
# 48841  [good, cut, sugar, consumpt, big, contributor,...
# 48842                [start, metformin, insulin, resist]
# 48843  [syndrom, tie, insulin, resist, pco, hypothyroid]
# 48844  [question, mark, pco, hormon, marker, overweig...
# 48845  [insulin, resist, diagnosi, start, rear, head,...
# 48846                                      [hypothyroid]
# 48847                                         [treatabl]
# 48848             [good, step, healthi, revers, process]
# 48849                           [worri, scari, diagnosi]
# 48850                             [inkl, symptom, treat]
# 48851                              [pregnant, ?, forget]
# 48852                                      [mother, pco]
# 48853                           [22, experienc, symptom]
# 48854  [blood, test, march, prolactin, level, 32ml, s...
# 48855                                             [fine]
# 48856                  [month, ve, notic, bit, crappier]
# 48857  [knee, will, occasion, sore, sleepi, lot, cold...
# 48858    [lot, symptom, point, hyperthyroid, think, pco]
# 48859                        [met, doctor, order, blood]
# 48860                                     [sure, deciph]
# 48861                                          [help, ?]
# 48863                                           [tsh, 1]
# 48864                                               [15]
# 48865                                        [freet4, 0]
# 48866                                                [9]
#
#                                                      bow  stem_len
# 0      [(104, 1), (234, 1), (1121, 1), (1249, 1), (13...         7
# 1      [(9, 2), (155, 1), (178, 1), (194, 1), (1356, 1)]         9
# 2                                  [(966, 1), (1809, 1)]         2
# 3                                            [(1809, 1)]         3
# 4                                            [(1374, 1)]         2
# 5                                              [(26, 1)]         2
# 6                [(98, 1), (353, 1), (863, 1), (991, 1)]         6
# 7                [(26, 1), (114, 1), (531, 1), (918, 1)]         4
# 8                                                     []         2
# 9                                             [(444, 1)]         3
# 10                                   [(9, 1), (1598, 1)]         3
# 11     [(3, 1), (178, 1), (447, 1), (1370, 1), (1864,...         6
# 12                      [(654, 1), (1032, 1), (1598, 1)]         5
# 13                                  [(383, 1), (498, 1)]         2
# 14                                [(1251, 1), (1338, 1)]         5
# 15     [(70, 1), (104, 1), (170, 1), (444, 1), (1747,...         7
# 16            [(261, 1), (444, 1), (1032, 1), (1336, 1)]         9
# 17                      [(444, 1), (1178, 1), (1300, 1)]         3
# 18                        [(144, 1), (565, 1), (966, 1)]         5
# 20     [(1, 1), (447, 1), (527, 1), (918, 1), (1300, ...         6
# 21                      [(319, 1), (1665, 1), (1674, 1)]         3
# 22               [(32, 1), (43, 1), (104, 1), (1375, 1)]         4
# 23               [(18, 1), (70, 1), (342, 1), (1375, 1)]         5
# 24                       [(70, 1), (1032, 1), (1712, 1)]         7
# 25                        [(70, 1), (109, 1), (1712, 1)]         3
# 26                                           [(1082, 1)]         2
# 27     [(16, 1), (82, 1), (131, 1), (444, 1), (457, 1...        10
# 29                                           [(1809, 1)]         1
# 30                                                    []         1
# 31                                             [(17, 1)]         3
# ...                                                  ...       ...
# 48836          [(85, 1), (170, 1), (1194, 1), (1671, 1)]         7
# 48837  [(944, 1), (1263, 1), (1386, 1), (1502, 1), (1...         5
# 48838  [(43, 1), (151, 1), (472, 1), (1382, 1), (1541...         6
# 48839                                         [(117, 1)]         3
# 48840                      [(78, 1), (98, 1), (1663, 1)]         6
# 48841  [(48, 1), (110, 1), (383, 1), (472, 1), (586, ...         7
# 48842                                [(40, 1), (566, 1)]         4
# 48843                              [(566, 1), (1568, 1)]         6
# 48844                      [(1, 1), (166, 1), (1779, 1)]        10
# 48845  [(9, 1), (40, 1), (104, 1), (566, 1), (1036, 1...         9
# 48846                                                 []         1
# 48847                                                 []         1
# 48848          [(234, 1), (472, 1), (580, 1), (1318, 1)]         5
# 48849                               [(47, 1), (1619, 1)]         3
# 48850                              [(458, 1), (1541, 1)]         3
# 48851                    [(568, 1), (966, 1), (1528, 1)]         3
# 48852                                        [(1032, 1)]         2
# 48853                    [(209, 1), (458, 1), (1752, 1)]         3
# 48854  [(40, 1), (86, 1), (910, 1), (1026, 1), (1622,...         9
# 48855                                          [(83, 1)]         1
# 48856              [(8, 1), (20, 1), (211, 1), (412, 1)]         5
# 48857  [(77, 1), (132, 1), (141, 1), (368, 1), (717, ...         8
# 48858                      [(89, 1), (141, 1), (458, 1)]         6
# 48859                               [(220, 1), (910, 1)]         4
# 48860                                         [(457, 1)]         2
# 48861                                [(50, 1), (966, 1)]         2
# 48863                                          [(91, 1)]         2
# 48864                                          [(97, 1)]         1
# 48865                                                 []         2
# 48866                                         [(275, 1)]         1
#
# [42606 rows x 7 columns]

# %%
data['glove_features'] = list(map(lambda sen_group:
                                      get_w2v_features(model, sen_group),
                                      new_dt.text))
# Out:
# /home/alice/Mines/paradec/paradec/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   # This is added back by InteractiveShellApp.init_path()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-e8bfab15dde7> in <module>
#       1 data['glove_features'] = list(map(lambda sen_group:
#       2                                       get_w2v_features(model, sen_group),
# ----> 3                                       new_dt.text))
#
# ~/Mines/paradec/paradec/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~/Mines/paradec/paradec/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3192
#    3193         self._ensure_valid_index(value)
# -> 3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#    3196
#
# ~/Mines/paradec/paradec/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3389
#    3390             # turn me into an ndarray
# -> 3391             value = _sanitize_index(value, self.index, copy=False)
#    3392             if not isinstance(value, (np.ndarray, Index)):
#    3393                 if isinstance(value, list) and len(value) > 0:
#
# ~/Mines/paradec/paradec/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_index(data, index, copy)
#    3999
#    4000     if len(data) != len(index):
# -> 4001         raise ValueError('Length of values does not match length of ' 'index')
#    4002
#    4003     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
X_new_glove = np.array(list(map(np.array, new_dt.glove_features)))

# %%
new_dt['lda_features'] = list(map(lambda doc:
                                      document_to_lda_features(LDAmodel, doc),
                                      new_dt.bow))

# %%
X_new_lda = np.array(list(map(np.array, new_dt.lda_features)))

# %%
new_dt[(new_dt['stem_len']>0)&(new_dt['stem_len']<=10)]['prediction'] = clf.predict(X_new_lda)
# Out:
# /home/alice/Mines/paradec/paradec/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_dt
# Out:
#                                                     text  \
# 0      how about a divorce support group for those wh...
# 1      i know when i was divorced 6 years ago after 2...
# 2                        anyone have any other comments?
# 3             i'm welcoming all suggestions and comments
# 4                          i just need some sound advice
# 5                                   i have a dd who is 2
# 6      she is very smart, tall for her age, speaks in...
# 7          she appears to be 3 instead of just turning 2
# 8                          she goes to daycare full-time
# 9      it's an in-home daycare with only one other ch...
# 10                      a boy (andy) who is one year old
# 11     a few weeks ago she came home with a red mark ...
# 12     daycare mother said the little boy had hit her...
# 13                                     okay, no big deal
# 14     then she mentioned that my dd likes to push an...
# 15     i don't have any friends with children, so the...
# 16     so, yesterday when i got to daycare to pick my...
# 17        she was on the floor playing with the children
# 18     i said, what's wrong?  she said "your dd is ab...
# 19     "  i said what happened?  she said that while ...
# 20     she went in to find him on the floor and as th...
# 21     i was confused as to what exactly i was suppos...
# 22     so finally i said well if i had been here, i w...
# 23     5 hours later is not the time, in my opinion, ...
# 24     i told the daycare mother that i was not oppos...
# 25     and i thought she had told me she put her in t...
# 26         i'm really at my wits end with this situation
# 27     am i not doing what needs to be done?  i feel ...
# 28     why am i being blamed for something when i'm a...
# 29                                        please comment
# ...                                                  ...
# 48837  i need to phone back to double check the thyro...
# 48838  well, i know it's hard but it's good that you ...
# 48839          pcos really is very common and manageable
# 48840  about 10% of the reproductive age female popul...
# 48841  i think it is very good that you are trying to...
# 48842  you may also have to start metformin, since it...
# 48843  these syndromes all seem to be tied together- ...
# 48844  there is a question mark for me about the pcos...
# 48845  but the insulin resistance diagnosis is starti...
# 48846                         i also have hypothyroidism
# 48847                           all of this is treatable
# 48848  it is good that you know because now you can t...
# 48849  please do not worry- this is not a scary diagn...
# 48850  you must have had some inkling that you had so...
# 48851           are you trying to get pregnant? i forget
# 48852                                 my mother had pcos
# 48853  i'm 22 and have been experiencing some of the ...
# 48854  i got my blood test done in march and my prola...
# 48855                      which is has been fine for me
# 48856  but over the last few months, i've noticed tha...
# 48857  my knee will occasionally be sore, i'm really ...
# 48858  a lot of symptoms that's point toward hyperthy...
# 48859  i met with my doctor and she ordered some bloo...
# 48860  they came in but i'm not sure how to decipher ...
# 48861                            can anyone help me out?
# 48862                                    my results are:
# 48863                                             tsh: 1
# 48864                                                 15
# 48865                                         freet4 = 0
# 48866                                                  9
#
#                                           tokenized_text  \
# 0      [how, about, a, divorce, support, group, for, ...
# 1      [i, know, when, i, was, divorced, 6, years, ag...
# 2                [anyone, have, any, other, comments, ?]
# 3      [i, m, welcoming, all, suggestions, and, comme...
# 4                   [i, just, need, some, sound, advice]
# 5                           [i, have, a, dd, who, is, 2]
# 6      [she, is, very, smart, tall, for, her, age, sp...
# 7      [she, appears, to, be, 3, instead, of, just, t...
# 8                     [she, goes, to, daycare, fulltime]
# 9      [it, s, an, inhome, daycare, with, only, one, ...
# 10               [a, boy, andy, who, is, one, year, old]
# 11     [a, few, weeks, ago, she, came, home, with, a,...
# 12     [daycare, mother, said, the, little, boy, had,...
# 13                                 [okay, no, big, deal]
# 14     [then, she, mentioned, that, my, dd, likes, to...
# 15     [i, do, nt, have, any, friends, with, children...
# 16     [so, yesterday, when, i, got, to, daycare, to,...
# 17     [she, was, on, the, floor, playing, with, the,...
# 18     [i, said, what, s, wrong, ?, she, said, your, ...
# 19     [i, said, what, happened, ?, she, said, that, ...
# 20     [she, went, in, to, find, him, on, the, floor,...
# 21     [i, was, confused, as, to, what, exactly, i, w...
# 22     [so, finally, i, said, well, if, i, had, been,...
# 23     [5, hours, later, is, not, the, time, in, my, ...
# 24     [i, told, the, daycare, mother, that, i, was, ...
# 25     [and, i, thought, she, had, told, me, she, put...
# 26     [i, m, really, at, my, wits, end, with, this, ...
# 27     [am, i, not, doing, what, needs, to, be, done,...
# 28     [why, am, i, being, blamed, for, something, wh...
# 29                                     [please, comment]
# ...                                                  ...
# 48837  [i, need, to, phone, back, to, double, check, ...
# 48838  [well, i, know, it, s, hard, but, it, s, good,...
# 48839  [pcos, really, is, very, common, and, manageable]
# 48840  [about, 10, of, the, reproductive, age, female...
# 48841  [i, think, it, is, very, good, that, you, are,...
# 48842  [you, may, also, have, to, start, metformin, s...
# 48843  [these, syndromes, all, seem, to, be, tied, to...
# 48844  [there, is, a, question, mark, for, me, about,...
# 48845  [but, the, insulin, resistance, diagnosis, is,...
# 48846                    [i, also, have, hypothyroidism]
# 48847                     [all, of, this, is, treatable]
# 48848  [it, is, good, that, you, know, because, now, ...
# 48849  [please, do, not, worry, this, is, not, a, sca...
# 48850  [you, must, have, had, some, inkling, that, yo...
# 48851  [are, you, trying, to, get, pregnant, ?, i, fo...
# 48852                            [my, mother, had, pcos]
# 48853  [i, m, 22, and, have, been, experiencing, some...
# 48854  [i, got, my, blood, test, done, in, march, and...
# 48855              [which, is, has, been, fine, for, me]
# 48856  [but, over, the, last, few, months, i, ve, not...
# 48857  [my, knee, will, occasionally, be, sore, i, m,...
# 48858  [a, lot, of, symptoms, that, s, point, toward,...
# 48859  [i, met, with, my, doctor, and, she, ordered, ...
# 48860  [they, came, in, but, i, m, not, sure, how, to...
# 48861                    [can, anyone, help, me, out, ?]
# 48862                                 [my, results, are]
# 48863                                           [tsh, 1]
# 48864                                               [15]
# 48865                                        [freet4, 0]
# 48866                                                [9]
#
#                                        stopwords_removed  \
# 0      [divorce, support, group, process, divorced, n...
# 1      [divorced, 6, years, ago, 23, years, marriage,...
# 2                                          [comments, ?]
# 3                     [welcoming, suggestions, comments]
# 4                                        [sound, advice]
# 5                                                [dd, 2]
# 6        [smart, tall, age, speaks, complete, sentences]
# 7                               [appears, 3, turning, 2]
# 8                                    [daycare, fulltime]
# 9                               [inhome, daycare, child]
# 10                                     [boy, andy, year]
# 11                   [weeks, ago, red, mark, eye, asked]
# 12                      [daycare, mother, boy, hit, toy]
# 13                                           [big, deal]
# 14                    [mentioned, dd, likes, push, andy]
# 15      [nt, friends, children, time, dd, kids, daycare]
# 16     [yesterday, daycare, pick, child, daycare, mot...
# 17                            [floor, playing, children]
# 18                         [wrong, ?, dd, abusing, andy]
# 19     [happened, ?, daycare, mother, fixing, lunch, ...
# 20              [find, floor, day, black, eye, appeared]
# 21                         [confused, exactly, supposed]
# 22                        [finally, well, corrected, nt]
# 23                    [5, hours, time, opinion, correct]
# 24     [told, daycare, mother, opposed, putting, dd, ...
# 25                                 [thought, told, time]
# 26                                     [wits, situation]
# 27     [?, feel, paying, good, money, child, care, wo...
# 28     [blamed, work, ?, stage, dd, going, ?, brother...
# 29                                             [comment]
# ...                                                  ...
# 48837            [phone, double, check, thyroid, levels]
# 48838   [well, hard, good, definitive, diagnosis, treat]
# 48839                         [pcos, common, manageable]
# 48840  [10, reproductive, age, female, population, pcos]
# 48841  [good, cut, sugar, consumption, big, contribut...
# 48842            [start, metformin, insulin, resistance]
# 48843  [syndromes, tied, insulin, resistance, pcos, h...
# 48844  [question, mark, pcos, hormonal, markers, over...
# 48845  [insulin, resistance, diagnosis, starting, rea...
# 48846                                   [hypothyroidism]
# 48847                                        [treatable]
# 48848         [good, steps, healthy, reversing, process]
# 48849                          [worry, scary, diagnosis]
# 48850                         [inkling, symptoms, treat]
# 48851                              [pregnant, ?, forget]
# 48852                                     [mother, pcos]
# 48853                       [22, experiencing, symptoms]
# 48854  [blood, test, march, prolactin, level, 32ml, s...
# 48855                                             [fine]
# 48856               [months, ve, noticed, bit, crappier]
# 48857  [knee, will, occasionally, sore, sleepy, lot, ...
# 48858  [lot, symptoms, point, hyperthyroidism, thinki...
# 48859                      [met, doctor, ordered, blood]
# 48860                                   [sure, decipher]
# 48861                                          [help, ?]
# 48862                                                 []
# 48863                                           [tsh, 1]
# 48864                                               [15]
# 48865                                        [freet4, 0]
# 48866                                                [9]
#
#                                          lemmatized_text  \
# 0      [divorce, support, group, process, divorced, n...
# 1      [divorced, 6, year, ago, 23, year, marriage, g...
# 2                                           [comment, ?]
# 3                       [welcoming, suggestion, comment]
# 4                                        [sound, advice]
# 5                                                [dd, 2]
# 6         [smart, tall, age, speaks, complete, sentence]
# 7                               [appears, 3, turning, 2]
# 8                                    [daycare, fulltime]
# 9                               [inhome, daycare, child]
# 10                                     [boy, andy, year]
# 11                    [week, ago, red, mark, eye, asked]
# 12                      [daycare, mother, boy, hit, toy]
# 13                                           [big, deal]
# 14                     [mentioned, dd, like, push, andy]
# 15           [nt, friend, child, time, dd, kid, daycare]
# 16     [yesterday, daycare, pick, child, daycare, mot...
# 17                               [floor, playing, child]
# 18                         [wrong, ?, dd, abusing, andy]
# 19     [happened, ?, daycare, mother, fixing, lunch, ...
# 20              [find, floor, day, black, eye, appeared]
# 21                         [confused, exactly, supposed]
# 22                        [finally, well, corrected, nt]
# 23                     [5, hour, time, opinion, correct]
# 24     [told, daycare, mother, opposed, putting, dd, ...
# 25                                 [thought, told, time]
# 26                                      [wit, situation]
# 27     [?, feel, paying, good, money, child, care, wo...
# 28     [blamed, work, ?, stage, dd, going, ?, brother...
# 29                                             [comment]
# ...                                                  ...
# 48837             [phone, double, check, thyroid, level]
# 48838   [well, hard, good, definitive, diagnosis, treat]
# 48839                         [pcos, common, manageable]
# 48840  [10, reproductive, age, female, population, pcos]
# 48841  [good, cut, sugar, consumption, big, contribut...
# 48842            [start, metformin, insulin, resistance]
# 48843  [syndrome, tied, insulin, resistance, pcos, hy...
# 48844  [question, mark, pcos, hormonal, marker, overw...
# 48845  [insulin, resistance, diagnosis, starting, rea...
# 48846                                   [hypothyroidism]
# 48847                                        [treatable]
# 48848          [good, step, healthy, reversing, process]
# 48849                          [worry, scary, diagnosis]
# 48850                          [inkling, symptom, treat]
# 48851                              [pregnant, ?, forget]
# 48852                                     [mother, pcos]
# 48853                        [22, experiencing, symptom]
# 48854  [blood, test, march, prolactin, level, 32ml, s...
# 48855                                             [fine]
# 48856                [month, ve, noticed, bit, crappier]
# 48857  [knee, will, occasionally, sore, sleepy, lot, ...
# 48858  [lot, symptom, point, hyperthyroidism, thinkin...
# 48859                      [met, doctor, ordered, blood]
# 48860                                   [sure, decipher]
# 48861                                          [help, ?]
# 48862                                                 []
# 48863                                           [tsh, 1]
# 48864                                               [15]
# 48865                                        [freet4, 0]
# 48866                                                [9]
#
#                                             stemmed_text  \
# 0      [divorc, support, group, process, divorc, nt, ...
# 1      [divorc, 6, year, ago, 23, year, marriag, god,...
# 2                                           [comment, ?]
# 3                             [welcom, suggest, comment]
# 4                                         [sound, advic]
# 5                                                [dd, 2]
# 6            [smart, tall, age, speak, complet, sentenc]
# 7                                   [appear, 3, turn, 2]
# 8                                      [daycar, fulltim]
# 9                                 [inhom, daycar, child]
# 10                                     [boy, andi, year]
# 11                      [week, ago, red, mark, eye, ask]
# 12                       [daycar, mother, boy, hit, toy]
# 13                                           [big, deal]
# 14                       [mention, dd, like, push, andi]
# 15            [nt, friend, child, time, dd, kid, daycar]
# 16     [yesterday, daycar, pick, child, daycar, mothe...
# 17                                  [floor, play, child]
# 18                            [wrong, ?, dd, abus, andi]
# 19     [happen, ?, daycar, mother, fix, lunch, left, ...
# 20                [find, floor, day, black, eye, appear]
# 21                             [confus, exactli, suppos]
# 22                            [final, well, correct, nt]
# 23                     [5, hour, time, opinion, correct]
# 24          [told, daycar, mother, oppos, put, dd, time]
# 25                                 [thought, told, time]
# 26                                         [wit, situat]
# 27     [?, feel, pay, good, money, child, care, work,...
# 28     [blame, work, ?, stage, dd, go, ?, brothersist...
# 29                                             [comment]
# ...                                                  ...
# 48837              [phone, doubl, check, thyroid, level]
# 48838       [well, hard, good, definit, diagnosi, treat]
# 48839                               [pco, common, manag]
# 48840            [10, reproduct, age, femal, popul, pco]
# 48841  [good, cut, sugar, consumpt, big, contributor,...
# 48842                [start, metformin, insulin, resist]
# 48843  [syndrom, tie, insulin, resist, pco, hypothyroid]
# 48844  [question, mark, pco, hormon, marker, overweig...
# 48845  [insulin, resist, diagnosi, start, rear, head,...
# 48846                                      [hypothyroid]
# 48847                                         [treatabl]
# 48848             [good, step, healthi, revers, process]
# 48849                           [worri, scari, diagnosi]
# 48850                             [inkl, symptom, treat]
# 48851                              [pregnant, ?, forget]
# 48852                                      [mother, pco]
# 48853                           [22, experienc, symptom]
# 48854  [blood, test, march, prolactin, level, 32ml, s...
# 48855                                             [fine]
# 48856                  [month, ve, notic, bit, crappier]
# 48857  [knee, will, occasion, sore, sleepi, lot, cold...
# 48858    [lot, symptom, point, hyperthyroid, think, pco]
# 48859                        [met, doctor, order, blood]
# 48860                                     [sure, deciph]
# 48861                                          [help, ?]
# 48862                                                 []
# 48863                                           [tsh, 1]
# 48864                                               [15]
# 48865                                        [freet4, 0]
# 48866                                                [9]
#
#                                                      bow  stem_len  \
# 0      [(104, 1), (234, 1), (1121, 1), (1249, 1), (13...         7
# 1      [(9, 2), (155, 1), (178, 1), (194, 1), (1356, 1)]         9
# 2                                  [(966, 1), (1809, 1)]         2
# 3                                            [(1809, 1)]         3
# 4                                            [(1374, 1)]         2
# 5                                              [(26, 1)]         2
# 6                [(98, 1), (353, 1), (863, 1), (991, 1)]         6
# 7                [(26, 1), (114, 1), (531, 1), (918, 1)]         4
# 8                                                     []         2
# 9                                             [(444, 1)]         3
# 10                                   [(9, 1), (1598, 1)]         3
# 11     [(3, 1), (178, 1), (447, 1), (1370, 1), (1864,...         6
# 12                      [(654, 1), (1032, 1), (1598, 1)]         5
# 13                                  [(383, 1), (498, 1)]         2
# 14                                [(1251, 1), (1338, 1)]         5
# 15     [(70, 1), (104, 1), (170, 1), (444, 1), (1747,...         7
# 16            [(261, 1), (444, 1), (1032, 1), (1336, 1)]         9
# 17                      [(444, 1), (1178, 1), (1300, 1)]         3
# 18                        [(144, 1), (565, 1), (966, 1)]         5
# 19     [(106, 1), (488, 1), (582, 1), (966, 1), (1032...        12
# 20     [(1, 1), (447, 1), (527, 1), (918, 1), (1300, ...         6
# 21                      [(319, 1), (1665, 1), (1674, 1)]         3
# 22               [(32, 1), (43, 1), (104, 1), (1375, 1)]         4
# 23               [(18, 1), (70, 1), (342, 1), (1375, 1)]         5
# 24                       [(70, 1), (1032, 1), (1712, 1)]         7
# 25                        [(70, 1), (109, 1), (1712, 1)]         3
# 26                                           [(1082, 1)]         2
# 27     [(16, 1), (82, 1), (131, 1), (444, 1), (457, 1...        10
# 28     [(1, 1), (12, 1), (16, 1), (82, 1), (131, 1), ...        16
# 29                                           [(1809, 1)]         1
# ...                                                  ...       ...
# 48837  [(944, 1), (1263, 1), (1386, 1), (1502, 1), (1...         5
# 48838  [(43, 1), (151, 1), (472, 1), (1382, 1), (1541...         6
# 48839                                         [(117, 1)]         3
# 48840                      [(78, 1), (98, 1), (1663, 1)]         6
# 48841  [(48, 1), (110, 1), (383, 1), (472, 1), (586, ...         7
# 48842                                [(40, 1), (566, 1)]         4
# 48843                              [(566, 1), (1568, 1)]         6
# 48844                      [(1, 1), (166, 1), (1779, 1)]        10
# 48845  [(9, 1), (40, 1), (104, 1), (566, 1), (1036, 1...         9
# 48846                                                 []         1
# 48847                                                 []         1
# 48848          [(234, 1), (472, 1), (580, 1), (1318, 1)]         5
# 48849                               [(47, 1), (1619, 1)]         3
# 48850                              [(458, 1), (1541, 1)]         3
# 48851                    [(568, 1), (966, 1), (1528, 1)]         3
# 48852                                        [(1032, 1)]         2
# 48853                    [(209, 1), (458, 1), (1752, 1)]         3
# 48854  [(40, 1), (86, 1), (910, 1), (1026, 1), (1622,...         9
# 48855                                          [(83, 1)]         1
# 48856              [(8, 1), (20, 1), (211, 1), (412, 1)]         5
# 48857  [(77, 1), (132, 1), (141, 1), (368, 1), (717, ...         8
# 48858                      [(89, 1), (141, 1), (458, 1)]         6
# 48859                               [(220, 1), (910, 1)]         4
# 48860                                         [(457, 1)]         2
# 48861                                [(50, 1), (966, 1)]         2
# 48862                                                 []         0
# 48863                                          [(91, 1)]         2
# 48864                                          [(97, 1)]         1
# 48865                                                 []         2
# 48866                                         [(275, 1)]         1
#
#                                             lda_features
# 0      [0.3889574408531189, 0.0035985582508146763, 0....
# 1      [0.14830075204372406, 0.004112637601792812, 0....
# 2      [0.010379879735410213, 0.009596155025064945, 0...
# 3      [0.015569516457617283, 0.01439423207193613, 0....
# 4      [0.5155695080757141, 0.01439423207193613, 0.01...
# 5      [0.015569516457617283, 0.01439423207193613, 0....
# 6      [0.006227806676179171, 0.20575812458992004, 0....
# 7      [0.006227806676179171, 0.005757692735642195, 0...
# 8      [0.031139032915234566, 0.02878846414387226, 0....
# 9      [0.015569516457617283, 0.01439423207193613, 0....
# 10     [0.010379677638411522, 0.009596155025064945, 0...
# 11     [0.33950310945510864, 0.1731421947479248, 0.00...
# 12     [0.0077847582288086414, 0.007197116035968065, ...
# 13     [0.010379677638411522, 0.009596155025064945, 0...
# 14     [0.34371301531791687, 0.009596155025064945, 0....
# 15     [0.17712852358818054, 0.004798077512532473, 0....
# 16     [0.20636630058288574, 0.005757692735642195, 0....
# 17     [0.26008033752441406, 0.007197116035968065, 0....
# 18     [0.0077847582288086414, 0.007197116035968065, ...
# 19     [0.22308948636054993, 0.10287884622812271, 0.0...
# 20     [0.1481362134218216, 0.14888201653957367, 0.14...
# 21     [0.0077847582288086414, 0.4233189821243286, 0....
# 22     [0.21042844653129578, 0.005758100189268589, 0....
# 23     [0.20743295550346375, 0.005757692735642195, 0....
# 24     [0.0077847582288086414, 0.25743550062179565, 0...
# 25     [0.007784758694469929, 0.2574429214000702, 0.0...
# 26     [0.015569516457617283, 0.514394223690033, 0.01...
# 27     [0.0034598924685269594, 0.2103283405303955, 0....
# 28     [0.0023953102063387632, 0.26806575059890747, 0...
# 29     [0.015569516457617283, 0.01439423207193613, 0....
# ...                                                  ...
# 48837  [0.33852317929267883, 0.338131308555603, 0.004...
# 48838  [0.00444843340665102, 0.14730511605739594, 0.1...
# 48839  [0.015569516457617283, 0.514394223690033, 0.01...
# 48840  [0.007800045423209667, 0.25760510563850403, 0....
# 48841  [0.15095439553260803, 0.1471520960330963, 0.00...
# 48842  [0.010379677638411522, 0.009596155025064945, 0...
# 48843  [0.010379677638411522, 0.342929482460022, 0.00...
# 48844  [0.0077847582288086414, 0.007197116035968065, ...
# 48845  [0.0038923791144043207, 0.23505009710788727, 0...
# 48846  [0.031139032915234566, 0.02878846414387226, 0....
# 48847  [0.031139032915234566, 0.02878846414387226, 0....
# 48848  [0.21155066788196564, 0.005757692735642195, 0....
# 48849  [0.010379677638411522, 0.009596155025064945, 0...
# 48850  [0.010379677638411522, 0.34292951226234436, 0....
# 48851  [0.5465477705001831, 0.007197116035968065, 0.2...
# 48852  [0.015569517388939857, 0.014394233003258705, 0...
# 48853  [0.0077847582288086414, 0.2571971118450165, 0....
# 48854  [0.38020414113998413, 0.2561565935611725, 0.00...
# 48855  [0.015569516457617283, 0.01439423207193613, 0....
# 48856  [0.006227806676179171, 0.005757692735642195, 0...
# 48857  [0.22580920159816742, 0.11594267934560776, 0.0...
# 48858  [0.0077847582288086414, 0.007197116035968065, ...
# 48859  [0.010379677638411522, 0.009596155025064945, 0...
# 48860  [0.015569516457617283, 0.01439423207193613, 0....
# 48861  [0.010380001738667488, 0.009596155025064945, 0...
# 48862  [0.031139032915234566, 0.02878846414387226, 0....
# 48863  [0.015569516457617283, 0.01439423207193613, 0....
# 48864  [0.015569514594972134, 0.014394230209290981, 0...
# 48865  [0.031139032915234566, 0.02878846414387226, 0....
# 48866  [0.015569516457617283, 0.01439423207193613, 0....
#
# [48867 rows x 8 columns]

# %%
data.intent.unique()
# Out:
# array(['alcohol', 'eatingDisorders', 'pathology', 'drugAddiction',
#        'smoking', 'treatment', 'sleep', 'infoPatient', 'pain', 'activity',
#        'incomprehension', 'negativeEmo', 'positiveEmo', 'fallback',
#        'social', 'agree', 'disagree', 'hello', 'bye', 'risk'],
#       dtype=object)

# %%
new_dt[new_dt.prediction == 'eatingDisorders']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-156-99d71a0b3195> in <module>
# ----> 1 new_dt[new_dt.prediction == 'eatingDisorders']
#
# ~/Mines/paradec/paradec/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'prediction'

# %% [markdown]
# sentences embeddings
#
# 1. biLSTM
# 2. CNN
# 3. Emlo
#
# different clustering models  as evaluation
#
# purity + metrics
#
# classification on obrained features
#
# one-shot

# %% [markdown]
# ** Further experiments with Sentence Representations
#
# - use bidirectional LSTM to represent sentences
# Each iput word is represented by concatenation of LDA and Word2Vec vectors
#
# - use convolutional network
# Each iput word is represented by concatenation of LDA, Word2Vec vectors  and position information

# %% [markdown]
# too long sentences > 30
#
# multiclass classification
#
# mlp

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers=1):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers

        self.c1 = nn.Conv1d(input_size, hidden_size, 2)
        self.p1 = nn.AvgPool1d(2)
        self.c2 = nn.Conv1d(hidden_size, hidden_size, 1)
        self.p2 = nn.AvgPool1d(2)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=0.01)
        self.out = nn.Linear(hidden_size, output_size)

    def forward(self, inputs, hidden):
        batch_size = inputs.size(1)
        
        # Turn (seq_len x batch_size x input_size) into (batch_size x input_size x seq_len) for CNN
        inputs = inputs.transpose(0, 1).transpose(1, 2)

        # Run through Conv1d and Pool1d layers
        c = self.c1(inputs)
        p = self.p1(c)
        c = self.c2(p)
        p = self.p2(c)

        # Turn (batch_size x hidden_size x seq_len) back into (seq_len x batch_size x hidden_size) for RNN
        p = p.transpose(1, 2).transpose(0, 1)
        
        p = F.tanh(p)
        output, hidden = self.gru(p, hidden)
        conv_seq_len = output.size(0)
        output = output.view(conv_seq_len * batch_size, self.hidden_size) # Treating (conv_seq_len x batch_size) as batch_size for linear layer
        output = F.tanh(self.out(output))
        output = output.view(conv_seq_len, -1, self.output_size)
        return output, hidden

# %%
input_size = 20 #num topics
hidden_size = 50
output_size = 7
batch_size = 5
n_layers = 2
seq_len = 15 #number of examples

rnn = RNN(input_size, hidden_size, output_size, n_layers=n_layers)

inputs = Variable(torch.rand(seq_len, batch_size, input_size)) # seq_len x batch_size x 
outputs, hidden = rnn(inputs, None)
print('outputs', outputs.size()) # conv_seq_len x batch_size x output_size
print('hidden', hidden.size()) # n_layers x batch_size x hidden_size
# Out:
# /home/alice/Mines/paradec/paradec/lib/python3.6/site-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# outputs torch.Size([3, 5, 7])
# hidden torch.Size([2, 5, 50])

# %%
inputs.size()
# Out:
# torch.Size([15, 5, 20])

# %%
inputs[0][0]
# Out:
# tensor([0.3456, 0.3990, 0.2212, 0.5093, 0.2816, 0.2991, 0.8876, 0.2649, 0.2128,
#         0.2380, 0.1750, 0.6771, 0.4144, 0.0417, 0.7325, 0.4776, 0.2434, 0.5489,
#         0.4855, 0.0281])

# %%
outputs[0][0]
# Out:
# tensor([ 0.0170,  0.0506, -0.0245,  0.0137,  0.0220, -0.1867, -0.1126],
#        grad_fn=<SelectBackward>)

# %% [markdown]
# ### batched

# %%
bi_clf(X_encoded[3])
# Out:
# /home/alice/Mines/paradec/paradec/lib/python3.6/site-packages/ipykernel_launcher.py:23: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# tensor([[-3.0144, -3.0191, -2.9914, -3.0634, -2.9738, -3.0705, -2.9834, -3.0689,
#          -2.9719, -2.9261, -2.9284, -2.9812, -2.9337, -3.0683, -2.8504, -3.0134,
#          -3.0271, -2.9392, -3.0880, -3.0383]], grad_fn=<LogSoftmaxBackward>)

# %%
class BiLSTMC(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, label_size, batch_size, dropout=0.5):
        super(BiLSTMC, self).__init__()
        self.hidden_dim = hidden_dim
        self.batch_size = batch_size
        self.dropout = dropout
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(input_size=embedding_dim, hidden_size=hidden_dim, bidirectional=True)
        self.hidden2label = nn.Linear(hidden_dim*2, label_size)
        self.hidden = self.init_hidden()

    def init_hidden(self):
        # first is the hidden h
        # second is the cell c
        return (Variable(torch.zeros(2, self.batch_size, self.hidden_dim)),
                Variable(torch.zeros(2, self.batch_size, self.hidden_dim)))

    def forward(self, sentence):
        x = self.embeddings(sentence).view(len(sentence), self.batch_size, -1)
        lstm_out, self.hidden = self.lstm(x, self.hidden)
        y = self.hidden2label(lstm_out[-1])
        log_probs = F.log_softmax(y)
        return log_probs

# %%
bi_clf = BiLSTMC(32, 124, encoder.vocab_size, 20, 1)

# %%
optimizer = torch.optim.Adam(bi_clf.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# %%
train_idx = y_train.index
test_idx = y_test.index

# %%
X_encoded = nn.utils.rnn.pad_sequence(list(map(lambda x: encoder.encode(x), data['text'].values)))

# %%
vXtrain = torch.index_select(X_encoded, 1, Variable(torch.from_numpy(train_idx.values).long()))
vXtest = torch.index_select(X_encoded, 1, Variable(torch.from_numpy(test_idx.values).long()))
vytrain = torch.from_numpy(pd.get_dummies(y).loc[y_train.index].values)
vytest = torch.from_numpy(pd.get_dummies(y).loc[y_test.index].values)

# %%
vXtrain[0].size()
# Out:
# torch.Size([2000])

# %%
vytrain.size()
# Out:
# torch.Size([2000, 20])

# %%
losses = []

for epoch in range(10):
    optimizer.zero_grad()
    yhat = bi_clf(vXtrain)
    loss = criterion(yhat, vytrain)
    loss.backward()
    losses.append(loss.data.item())
    optimizer.step()

# %%
from torchnlp.word_to_vector import GloVe

# %%
vectors = GloVe(dim=30, name='6B')

# %%
encoder.vocab_size
# Out:
# 2812

# %%
from torchnlp.word_to_vector import FastText

vectors = FastText()
# Load vectors for any word as a `torch.FloatTensor`
vectors['hello']  # RETURNS: [torch.FloatTen

# %% [markdown]
# ## HDP modeling

# %%
from gensim.models import HdpModel

# %%
list(filter(lambda x: len(x) > 0, corpus))

# %%
hdp = HdpModel(corpus=list(filter(lambda x: len(x) > 0, corpus)), id2word=dictionary)

# %%
hdp.print_topics()

# %%
def Diff(li1, li2): 
    li_dif = [i for i in li1 + li2 if i not in li1 or i not in li2] 
    return tuple(li_dif)

# %%
Diff(data.tokenized_text[0], data.spacy_tokens[0])
# Out:
# ['m', '’m']

# %%
data.spacy_tokens[0]
# Out:
# [i, ’m, drinking, at, least, a, bottle, of, wine, a, day, in, the, week]

# %%
data[['tokenized_text', 'spacy_tokens']]\
    .apply(lambda x: Diff(x['tokenized_text'], x['spacy_tokens']), axis=1).sort_values(ascending=False).drop_duplicates()
# Out:
# 2793                                     (zpill, z, pill)
# 2615                                     (zdrug, z, drug)
# 3149                         (wrongheaded, wrong, headed)
# 2648                     (wouldnt, 8am, would, nt, 8, am)
# 2897                                       (wont, wo, nt)
# 1814                                 (weekend, week, end)
# 616                                      (weedfree, free)
# 507                                      (wan, na, wanna)
# 1882                                     (thats, that, s)
# 3055                 (secondhand, 34, second, hand, 3, 4)
# 20                 (reducingstopping, reducing, stopping)
# 1731                               (pingpong, ping, pong)
# 630                      (percosetnorco, percoset, norco)
# 617     (onandoff, opiateopioid, on, and, off, opiate,...
# 526                      (norcosopiates, norcos, opiates)
# 2848                             (nighttime, night, time)
# 2891                         (middleclass, middle, class)
# 3039                               (longtime, long, time)
# 118                                (longterm, long, term)
# 171                                          (ive, i, ve)
# 2480                           (im, mdmax, i, m, mdma, x)
# 164                                               (im, m)
# 601                                            (im, i, m)
# 1442                         (heartbroken, heart, broken)
# 2767                                   (havent, have, nt)
# 2371                                 (haven, t, have, nt)
# 1093                                 (flulike, flu, like)
# 2745                 (exerciseinduced, exercise, induced)
# 653                                      (ecigs, e, cigs)
# 3054                                       (ecig, e, cig)
#                               ...
# 509                                        (35mg, 35, mg)
# 2940                                       (355c, 355, c)
# 2668                                           (34, 3, 4)
# 627                                      (320mg, 320, mg)
# 2607                                       (3040, 30, 40)
# 188                                          (2mg, 2, mg)
# 2347                                       (25mg, 25, mg)
# 197                                            (25, 2, 5)
# 97                             (23, won, t, 2, 3, wo, nt)
# 2522                                           (23, 2, 3)
# 2872                             (22yearold, 22year, old)
# 2666                                       (2024, 20, 24)
# 626                                      (200mg, 200, mg)
# 1194                                           (1m, 1, m)
# 2921                             (18yearold, 18year, old)
# 38                                         (1620, 16, 20)
# 2528                                         (150mg, 150)
# 2996                                 (15095mm, 15095, mm)
# 2657                                           (13, 1, 3)
# 2435                                       (1215, 12, 15)
# 622                                        (1213, 12, 13)
# 2909                             (120142bpm, 120, 142bpm)
# 2889                                   (115120, 115, 120)
# 232            (11001200, 8301000, 1100, 1200, 830, 1000)
# 2771                                       (10pm, 10, pm)
# 2502                                       (10mg, 10, mg)
# 2930                             (106120bpm, 106, 120bpm)
# 546                      (10325, 350mg, 10, 325, 350, mg)
# 222                                        (1015, 10, 15)
# 1070                                                   ()
# Length: 109, dtype: object

# %%
data[['tokenized_text', 'spacy_tokens']].loc[509].values
# Out:
# array([list(['i', 'm', 'supposed', 'to', 'take', '6', '35mg', 'tablets', 'a', 'day', 'but', 'i', 'have', 'taken', '20', 'today']),
#        list(['i', 'm', 'supposed', 'to', 'take', '6', '35', 'mg', 'tablets', 'a', 'day', 'but', 'i', 'have', 'taken', '20', 'today'])],
#       dtype=object)
